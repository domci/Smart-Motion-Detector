# %%
#!/usr/bin/env python




################################################
# Import Libraries
################################################
from matplotlib import pyplot as plt
import os
import time
import json
import fnmatch
import cv2
import numpy as np
import requests
import datetime
import logging
from logging.handlers import TimedRotatingFileHandler
import datetime
import glob
from imutils.video import VideoStream
from IPython.display import clear_output



args =  {'classes': '/home/cichons/Smart-Motion-Detector/classes.txt',
         'weights': '/home/cichons/Smart-Motion-Detector/yolov3.weights',
         'config': '/home/cichons/Smart-Motion-Detector/yolov3.cfg',
         'stream':'rtsp://172.17.0.2:7447/5b75de05e4b0a018229f268f_2',
         'cam_name': 'Carport'
        }


################################################
# Configure Log Handler
################################################

logger = logging.getLogger("Rotating Log")
logger.setLevel(logging.INFO)

logname = '/home/cichons/motioneye/logs/object_detected.log'
handler = TimedRotatingFileHandler(logname, when="midnight", interval=1)
handler.suffix = "%Y%m%d"
logger.addHandler(handler)






################################################
# Load Stuff
################################################

# Load Pushover Key File
data=json.loads(open('/home/cichons/Smart-Motion-Detector/keys.json').read())




classes = None

with open(args['classes'], 'r') as f:
    classes = [line.strip() for line in f.readlines()]

COLORS = np.random.uniform(0, 255, size=(len(classes), 3))    






################################################
# Settings
################################################

class_ids = []
confidences = []
boxes = []
conf_threshold = 0.6
nms_threshold = 0.4
scale = 0.00392
time_between_push_notifications = 0 
px_dist = 70 # Minumum Distance in Pixels between current and prevouis Detection



target_classes = ['person',
 'bicycle',
 'car',
 'motorcycle',
 'bus',
 'truck'
]


# Pushover Settings:
data['pushover']['priority'] = 1 #2
data['pushover']['retry'] = 30 
data['pushover']['expire'] = 300


################################################
# Defining Functions
################################################




def get_output_layers(net):
    layer_names = net.getLayerNames()
    output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
    return output_layers


def draw_prediction(img, class_id, confidence, x, y, x_plus_w, y_plus_h):
    label = str(classes[class_id]) + ': ' + str(round(confidence*100, 2))
    color = COLORS[class_id]
    cv2.rectangle(img, (x,y), (x_plus_w,y_plus_h), color, 2)
    cv2.putText(img, label, (x-10,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)




mtime_last = 0
dtime_last = 0

net = cv2.dnn.readNet(args['weights'], args['config'])
centers_last = [-10, -10]
boxes_last = []




print("[INFO] warming up camera...")
vs = VideoStream(src=args['stream'], framerate=3).start()
time.sleep(2.0)


print('cam_name: ', args['cam_name'])
# Out:
# [INFO] warming up camera...
# cam_name:  Carport

# %%
i = 0
while True:
    image = vs.read()
    
    if i == 10:
        i = 0
        clear_output()
    
    now = datetime.datetime.now()
    camera_name = args['cam_name']
    confidences = []
    

    if image is not None:
        print('detecting Objects...')
        try:
            (Height, Width) = image.shape[:2]
            blob = cv2.dnn.blobFromImage(image, scale, (416,416), (0,0,0), True, crop=False)
            net.setInput(blob)
            outs = net.forward(get_output_layers(net))

            boxes = []
            class_ids = []
            dtime_cur = time.time()
            confidences = []
            centers = []
            for out in outs:
                for detection in out:
                    scores = detection[5:]
                    class_id = np.argmax(scores)
                    confidence = scores[class_id]
                    if confidence > conf_threshold and classes[class_id] in target_classes:
                        print(confidence)
                        try:
                            requests.get('http://192.168.1.22:8080/object_detected')
                        except Exception as e:
                            print(e)
                            continue
                        
                        print(classes[class_id] + ' detected')
                        print('confidence and class good')
                        
                        center_x = int(detection[0] * Width)
                        center_y = int(detection[1] * Height)
                        centers.append([center_x, center_y])
                        w = int(detection[2] * Width)
                        h = int(detection[3] * Height)
                        x = center_x - w / 2
                        y = center_y - h / 2
                        class_ids.append(class_id)
                        confidences.append(float(confidence))
                        boxes.append([x, y, w, h])

            
            if boxes == []:
                print("No Object Detected.")
                boxes_last = boxes
                centers_last = centers
                continue

            indices = cv2.dnn.NMSBoxes(boxes, confidences, conf_threshold, nms_threshold)
            
            if boxes == boxes_last:
                logger.info(str(datetime.datetime.now()) + '   ' + 'Objects where previously detected on: \'' + camera_name + '\'')
                print('Objects where previously detected.')
            else:
                print(boxes)
                print(boxes_last)
                for i in indices:
                    i = i[0]
                    box = boxes[i]
                    x = box[0]
                    y = box[1]
                    w = box[2]
                    h = box[3]
                    draw_prediction(image, class_ids[i], confidences[i], round(x), round(y), round(x+w), round(y+h))

                boxed_img_path = '/home/cichons/motioneye/videos/detections/'+ str(now) +'_'+ str(camera_name) + '.jpg' 
                cv2.imwrite(boxed_img_path, image)
                    

                # Calculate relative Distances between centers of new and previous detections:                                        
                distances = abs(np.array([np.array(centers) - np.array(obj) for obj in centers_last]))
                if len(distances) == 0:
                    distances = 1000
                    distances

                print('distances ', distances)
                print('centers ', centers)
                print('centers_last ', centers_last)
                print('boxes differ ', boxes != boxes_last)
                print('confidences good ', confidences)
                print('distances ok ', np.max(distances) > px_dist, distances)
                print('max distance ', np.max(distances))
                print('time between notifications? ', (dtime_cur - dtime_last) > time_between_push_notifications)
                

                if boxes != boxes_last and confidences and np.max(distances) > px_dist and (dtime_cur - dtime_last) > time_between_push_notifications:

                    # Write to Log File
                    logger.info(str(datetime.datetime.now()) + '   ' + ', '.join(list(set([classes[i] for i in class_ids]))) + ' detected on Camera: \'' + camera_name + '\'')

                    print(', '.join(list(set([classes[i] for i in class_ids]))) + ' detected!')

                    # Sent Push Notification via Pushover:
                    data['pushover']['message'] = ', '.join(list(set([classes[i] for i in class_ids]))) + ' detected!'

                    r = requests.post("https://api.pushover.net/1/messages.json", data = data['pushover'],
                    files = {
                      "attachment": (str(now) +'_'+ str(camera_name) + '.jpg', open(boxed_img_path, "rb"), "image/jpeg")
                    })

                    print(r.text)
                    dtime_last = dtime_cur
                else:
                    print("Detected: " + ', '.join(list(set([classes[i] for i in class_ids]))) + ". Notification unwanted.")
                    print('boxes differ?', boxes != boxes_last)
                    print('confidences good?', confidences)
                    print('distances to previous detections ok?', np.max(distances) > px_dist, distances)
                    print('time between notifications?', (dtime_cur - dtime_last) > time_between_push_notifications)
                    continue

            boxes_last = boxes
            centers_last = centers
            #centers = []

        except Exception as e:
            print(e)
            continue

    else:
        print('image not found')
        continue
    i = i + 1
    print(i)
# Out:
# detecting Objects...
# 0.94274133
# car detected
# confidence and class good
# [[266.0, 61.0, 184, 164]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 0]]]
# centers  [[358, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.942741334438324]
# distances ok  False [[[3 0]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.942741334438324]
# distances to previous detections ok? False [[[3 0]]]
# time between notifications? True
# detecting Objects...
# 0.8565503
# car detected
# confidence and class good
# [[267.5, 64.0, 183, 162]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 2]]]
# centers  [[359, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8565502762794495]
# distances ok  False [[[2 2]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8565502762794495]
# distances to previous detections ok? False [[[2 2]]]
# time between notifications? True
# detecting Objects...
# 0.91254187
# car detected
# confidence and class good
# [[266.0, 60.0, 188, 166]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 0]]]
# centers  [[360, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9125418663024902]
# distances ok  False [[[1 0]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9125418663024902]
# distances to previous detections ok? False [[[1 0]]]
# time between notifications? True
# detecting Objects...
# 0.940563
# car detected
# confidence and class good
# [[266.5, 59.0, 185, 168]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 0]]]
# centers  [[359, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9405630230903625]
# distances ok  False [[[2 0]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9405630230903625]
# distances to previous detections ok? False [[[2 0]]]
# time between notifications? True
# detecting Objects...
# 0.8838848
# car detected
# confidence and class good
# [[264.0, 61.5, 188, 165]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 1]]]
# centers  [[358, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8838847875595093]
# distances ok  False [[[3 1]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8838847875595093]
# distances to previous detections ok? False [[[3 1]]]
# time between notifications? True
# detecting Objects...
# 0.90563107
# car detected
# confidence and class good
# [[265.5, 58.5, 189, 169]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 0]]]
# centers  [[360, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9056310653686523]
# distances ok  False [[[1 0]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9056310653686523]
# distances to previous detections ok? False [[[1 0]]]
# time between notifications? True
# detecting Objects...
# 0.9020888
# car detected
# confidence and class good
# [[264.0, 60.0, 190, 168]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 1]]]
# centers  [[359, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9020888209342957]
# distances ok  False [[[2 1]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9020888209342957]
# distances to previous detections ok? False [[[2 1]]]
# time between notifications? True
# detecting Objects...
# 0.9598488
# car detected
# confidence and class good
# [[264.5, 60.0, 187, 166]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 0]]]
# centers  [[358, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9598488211631775]
# distances ok  False [[[3 0]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9598488211631775]
# distances to previous detections ok? False [[[3 0]]]
# time between notifications? True
# detecting Objects...
# 0.88757974
# car detected
# confidence and class good
# [[265.5, 63.5, 185, 163]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 2]]]
# centers  [[358, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8875797390937805]
# distances ok  False [[[3 2]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8875797390937805]
# distances to previous detections ok? False [[[3 2]]]
# time between notifications? True
# detecting Objects...
# 0.9087993
# car detected
# confidence and class good
# [[266.5, 62.5, 185, 165]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 2]]]
# centers  [[359, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9087992906570435]
# distances ok  False [[[2 2]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9087992906570435]
# distances to previous detections ok? False [[[2 2]]]
# time between notifications? True
# detecting Objects...
# 0.8215789
# car detected
# confidence and class good
# [[265.0, 61.0, 190, 166]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 1]]]
# centers  [[360, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8215789198875427]
# distances ok  False [[[1 1]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8215789198875427]
# distances to previous detections ok? False [[[1 1]]]
# time between notifications? True
# detecting Objects...
# 0.90586954
# car detected
# confidence and class good
# [[264.0, 63.0, 186, 164]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[4 2]]]
# centers  [[357, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9058695435523987]
# distances ok  False [[[4 2]]]
# max distance  4
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9058695435523987]
# distances to previous detections ok? False [[[4 2]]]
# time between notifications? True
# detecting Objects...
# 0.89661187
# car detected
# confidence and class good
# [[263.5, 58.5, 189, 169]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 0]]]
# centers  [[358, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8966118693351746]
# distances ok  False [[[3 0]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8966118693351746]
# distances to previous detections ok? False [[[3 0]]]
# time between notifications? True
# detecting Objects...
# 0.8933499
# car detected
# confidence and class good
# [[263.0, 60.5, 190, 167]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 1]]]
# centers  [[358, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8933498859405518]
# distances ok  False [[[3 1]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8933498859405518]
# distances to previous detections ok? False [[[3 1]]]
# time between notifications? True
# detecting Objects...
# 0.8919288
# car detected
# confidence and class good
# [[268.0, 22.5, 184, 201]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[ 1 20]]]
# centers  [[360, 123]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8919287919998169]
# distances ok  False [[[ 1 20]]]
# max distance  20
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8919287919998169]
# distances to previous detections ok? False [[[ 1 20]]]
# time between notifications? True
# detecting Objects...
# 0.9270019
# car detected
# confidence and class good
# [[267.5, 60.5, 185, 167]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 1]]]
# centers  [[360, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9270018935203552]
# distances ok  False [[[1 1]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9270018935203552]
# distances to previous detections ok? False [[[1 1]]]
# time between notifications? True
# detecting Objects...
# 0.8640819
# car detected
# confidence and class good
# [[265.5, 61.5, 187, 165]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 1]]]
# centers  [[359, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8640819191932678]
# distances ok  False [[[2 1]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8640819191932678]
# distances to previous detections ok? False [[[2 1]]]
# time between notifications? True
# detecting Objects...
# 0.90639657
# car detected
# confidence and class good
# [[264.5, 59.5, 189, 169]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 1]]]
# centers  [[359, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9063965678215027]
# distances ok  False [[[2 1]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9063965678215027]
# distances to previous detections ok? False [[[2 1]]]
# time between notifications? True
# detecting Objects...
# 0.9068388
# car detected
# confidence and class good
# [[265.5, 65.0, 187, 160]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 2]]]
# centers  [[359, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9068387746810913]
# distances ok  False [[[2 2]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9068387746810913]
# distances to previous detections ok? False [[[2 2]]]
# time between notifications? True
# detecting Objects...
# 0.9359699
# car detected
# confidence and class good
# [[267.0, 61.0, 184, 164]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 0]]]
# centers  [[359, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.935969889163971]
# distances ok  False [[[2 0]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.935969889163971]
# distances to previous detections ok? False [[[2 0]]]
# time between notifications? True
# detecting Objects...
# 0.913853
# car detected
# confidence and class good
# [[265.5, 63.5, 189, 163]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 2]]]
# centers  [[360, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9138529896736145]
# distances ok  False [[[1 2]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9138529896736145]
# distances to previous detections ok? False [[[1 2]]]
# time between notifications? True
# detecting Objects...
# 0.9558323
# car detected
# confidence and class good
# [[262.5, 60.5, 191, 165]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 0]]]
# centers  [[358, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.955832302570343]
# distances ok  False [[[3 0]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.955832302570343]
# distances to previous detections ok? False [[[3 0]]]
# time between notifications? True
# detecting Objects...
# 0.9120957
# car detected
# confidence and class good
# [[263.5, 58.5, 191, 169]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 0]]]
# centers  [[359, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9120957255363464]
# distances ok  False [[[2 0]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9120957255363464]
# distances to previous detections ok? False [[[2 0]]]
# time between notifications? True
# detecting Objects...
# 0.92234343
# car detected
# confidence and class good
# [[268.0, 60.0, 186, 166]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[0 0]]]
# centers  [[361, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9223434329032898]
# distances ok  False [[[0 0]]]
# max distance  0
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9223434329032898]
# distances to previous detections ok? False [[[0 0]]]
# time between notifications? True
# detecting Objects...
# 0.9413741
# car detected
# confidence and class good
# [[264.5, 58.0, 189, 172]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 1]]]
# centers  [[359, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9413741230964661]
# distances ok  False [[[2 1]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9413741230964661]
# distances to previous detections ok? False [[[2 1]]]
# time between notifications? True
# detecting Objects...
# 0.8563427
# car detected
# confidence and class good
# [[265.5, 62.0, 187, 166]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 2]]]
# centers  [[359, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8563426733016968]
# distances ok  False [[[2 2]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8563426733016968]
# distances to previous detections ok? False [[[2 2]]]
# time between notifications? True
# detecting Objects...
# 0.8506186
# car detected
# confidence and class good
# [[268.5, 58.0, 183, 170]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 0]]]
# centers  [[360, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8506186008453369]
# distances ok  False [[[1 0]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8506186008453369]
# distances to previous detections ok? False [[[1 0]]]
# time between notifications? True
# detecting Objects...
# 0.8524788
# car detected
# confidence and class good
# [[267.5, 58.5, 183, 167]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 1]]]
# centers  [[359, 142]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8524788022041321]
# distances ok  False [[[2 1]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8524788022041321]
# distances to previous detections ok? False [[[2 1]]]
# time between notifications? True
# detecting Objects...
# 0.8860751
# car detected
# confidence and class good
# [[266.5, 57.5, 187, 171]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 0]]]
# centers  [[360, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8860750794410706]
# distances ok  False [[[1 0]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8860750794410706]
# distances to previous detections ok? False [[[1 0]]]
# time between notifications? True
# detecting Objects...
# 0.869526
# car detected
# confidence and class good
# [[267.5, 59.5, 185, 167]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 0]]]
# centers  [[360, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8695260286331177]
# distances ok  False [[[1 0]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8695260286331177]
# distances to previous detections ok? False [[[1 0]]]
# time between notifications? True
# detecting Objects...
# 0.75688463
# car detected
# confidence and class good
# [[264.5, 62.5, 191, 165]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 2]]]
# centers  [[360, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.7568846344947815]
# distances ok  False [[[1 2]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.7568846344947815]
# distances to previous detections ok? False [[[1 2]]]
# time between notifications? True
# detecting Objects...
# 0.83338314
# car detected
# confidence and class good
# [[262.5, 59.5, 191, 169]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 1]]]
# centers  [[358, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8333831429481506]
# distances ok  False [[[3 1]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8333831429481506]
# distances to previous detections ok? False [[[3 1]]]
# time between notifications? True
# detecting Objects...
# 0.9199299
# car detected
# confidence and class good
# [[265.0, 60.0, 186, 166]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 0]]]
# centers  [[358, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9199299216270447]
# distances ok  False [[[3 0]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9199299216270447]
# distances to previous detections ok? False [[[3 0]]]
# time between notifications? True
# detecting Objects...
# 0.89657146
# car detected
# confidence and class good
# [[267.5, 65.5, 185, 161]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 3]]]
# centers  [[360, 146]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8965714573860168]
# distances ok  False [[[1 3]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8965714573860168]
# distances to previous detections ok? False [[[1 3]]]
# time between notifications? True
# detecting Objects...
# 0.87314737
# car detected
# confidence and class good
# [[268.0, 62.0, 184, 164]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 1]]]
# centers  [[360, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8731473684310913]
# distances ok  False [[[1 1]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8731473684310913]
# distances to previous detections ok? False [[[1 1]]]
# time between notifications? True
# detecting Objects...
# 0.9448213
# car detected
# confidence and class good
# [[267.5, 59.0, 183, 168]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 0]]]
# centers  [[359, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.944821298122406]
# distances ok  False [[[2 0]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.944821298122406]
# distances to previous detections ok? False [[[2 0]]]
# time between notifications? True
# detecting Objects...
# 0.9238416
# car detected
# confidence and class good
# [[267.0, 59.0, 182, 168]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 0]]]
# centers  [[358, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9238415956497192]
# distances ok  False [[[3 0]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9238415956497192]
# distances to previous detections ok? False [[[3 0]]]
# time between notifications? True
# detecting Objects...
# 0.94268984
# car detected
# confidence and class good
# [[266.5, 61.0, 185, 166]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 1]]]
# centers  [[359, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.942689836025238]
# distances ok  False [[[2 1]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.942689836025238]
# distances to previous detections ok? False [[[2 1]]]
# time between notifications? True
# detecting Objects...
# 0.92588204
# car detected
# confidence and class good
# [[266.5, 63.5, 187, 163]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 2]]]
# centers  [[360, 145]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9258820414543152]
# distances ok  False [[[1 2]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9258820414543152]
# distances to previous detections ok? False [[[1 2]]]
# time between notifications? True
# detecting Objects...
# 0.9039279
# car detected
# confidence and class good
# [[267.0, 60.0, 186, 166]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 0]]]
# centers  [[360, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9039279222488403]
# distances ok  False [[[1 0]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9039279222488403]
# distances to previous detections ok? False [[[1 0]]]
# time between notifications? True
# detecting Objects...
# 0.9311441
# car detected
# confidence and class good
# [[268.5, 62.0, 183, 164]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 1]]]
# centers  [[360, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.931144118309021]
# distances ok  False [[[1 1]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.931144118309021]
# distances to previous detections ok? False [[[1 1]]]
# time between notifications? True
# detecting Objects...
# 0.8968784
# car detected
# confidence and class good
# [[267.5, 58.5, 185, 169]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[1 0]]]
# centers  [[360, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8968784213066101]
# distances ok  False [[[1 0]]]
# max distance  1
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8968784213066101]
# distances to previous detections ok? False [[[1 0]]]
# time between notifications? True
# detecting Objects...
# 0.8623983
# car detected
# confidence and class good
# [[268.5, 57.5, 181, 171]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 0]]]
# centers  [[359, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.8623983263969421]
# distances ok  False [[[2 0]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.8623983263969421]
# distances to previous detections ok? False [[[2 0]]]
# time between notifications? True
# detecting Objects...
# 0.901387
# car detected
# confidence and class good
# [[265.5, 61.5, 187, 165]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 1]]]
# centers  [[359, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9013869762420654]
# distances ok  False [[[2 1]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9013869762420654]
# distances to previous detections ok? False [[[2 1]]]
# time between notifications? True
# detecting Objects...
# 0.95089525
# car detected
# confidence and class good
# [[267.5, 58.5, 183, 169]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 0]]]
# centers  [[359, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9508952498435974]
# distances ok  False [[[2 0]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9508952498435974]
# distances to previous detections ok? False [[[2 0]]]
# time between notifications? True
# detecting Objects...
# 0.93447614
# car detected
# confidence and class good
# [[266.0, 58.5, 184, 169]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 0]]]
# centers  [[358, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9344761371612549]
# distances ok  False [[[3 0]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9344761371612549]
# distances to previous detections ok? False [[[3 0]]]
# time between notifications? True
# detecting Objects...
# 0.91075385
# car detected
# confidence and class good
# [[267.0, 60.0, 182, 168]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[3 1]]]
# centers  [[358, 144]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9107538461685181]
# distances ok  False [[[3 1]]]
# max distance  3
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9107538461685181]
# distances to previous detections ok? False [[[3 1]]]
# time between notifications? True
# detecting Objects...
# 0.91971636
# car detected
# confidence and class good
# [[265.5, 59.0, 187, 168]]
# [[267.0, 59.5, 188, 167]]
# distances  [[[2 0]]]
# centers  [[359, 143]]
# centers_last  [[361, 143]]
# boxes differ  True
# confidences good  [0.9197163581848145]
# distances ok  False [[[2 0]]]
# max distance  2
# time between notifications?  True
# Detected: car. Notification unwanted.
# boxes differ? True
# confidences good? [0.9197163581848145]
# distances to previous detections ok? False [[[2 0]]]
# time between notifications? True
# detecting Objects...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-40d174eb2314> in <module>()
#      18             blob = cv2.dnn.blobFromImage(image, scale, (416,416), (0,0,0), True, crop=False)
#      19             net.setInput(blob)
# ---> 20             outs = net.forward(get_output_layers(net))
#      21
#      22             boxes = []
#
# KeyboardInterrupt:

# %%
# Out:
# 'person'
