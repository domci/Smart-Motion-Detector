# %%
#!/usr/bin/env python




################################################
# Import Libraries
################################################

import os
import time
import json
import fnmatch
import cv2
import numpy as np
import requests
import datetime
import logging
from logging.handlers import TimedRotatingFileHandler
import datetime
import shelve


args =  {'classes': '/home/cichons/Smart-Motion-Detector/classes.txt',
         'weights': '/home/cichons/Smart-Motion-Detector/yolov3.weights',
         'config': '/home/cichons/Smart-Motion-Detector/yolov3.cfg'}


################################################
# Configure Log Handler
################################################

logger = logging.getLogger("Rotating Log")
logger.setLevel(logging.INFO)

logname = '/home/cichons/unifi-video/logs/object_detected.log'
handler = TimedRotatingFileHandler(logname, when="midnight", interval=1)
handler.suffix = "%Y%m%d"
logger.addHandler(handler)






################################################
# Load Stuff
################################################

# Load Pushover Key File
data=json.loads(open('/home/cichons/Smart-Motion-Detector/keys.json').read())

# Load Camera UUIDs from file:
with open('/home/cichons/Smart-Motion-Detector/support_dbdevices.json') as f:
    support_dbdevices = json.load(f)

cameras = {}
for cam in support_dbdevices['cameras']:
    print('Found Camera: ' + cam['name'] + ' ' + cam['uuid'] )
    cameras[cam['name']] = cam['uuid']
del cam


classes = None

with open(args['classes'], 'r') as f:
    classes = [line.strip() for line in f.readlines()]

COLORS = np.random.uniform(0, 255, size=(len(classes), 3))    






################################################
# Settings
################################################



LOG_FILE = '/home/cichons/unifi-video/logs/recording.log'
WATCH_FOR = 'STOPPING REC'

class_ids = []
confidences = []
boxes = []
conf_threshold = 0.5
nms_threshold = 0.4
scale = 0.00392
time_between_push_notifications = 0 
px_dist = 20 # Minumum Distance in Pixels between current and prevouis Detection



target_classes = ['person',
 'bicycle',
 'car',
 'motorcycle',
 'bus',
 'truck'
]


# Pushover Settings:
data['priority'] = 1 #2
data['retry'] = 30 
data['expire'] = 300


################################################
# Defining Functions
################################################

# basic Python implementation of Unix tail for getting Tail of Log File
def tail(file, n):
    with open(file, "r") as f:
#         f.seek (0, 2)           # Seek @ EOF
#         fsize = f.tell()        # Get Size
#         f.seek (max (fsize-1024, 0), 0) # Set pos @ last n chars
        lines = f.readlines()       # Read to end
    lines = lines[-n:]    # Get last n lines
    return lines




def get_output_layers(net):
    layer_names = net.getLayerNames()
    output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
    return output_layers


def draw_prediction(img, class_id, confidence, x, y, x_plus_w, y_plus_h):
    label = str(classes[class_id]) + ': ' + str(round(confidence*100, 2))
    color = COLORS[class_id]
    cv2.rectangle(img, (x,y), (x_plus_w,y_plus_h), color, 2)
    cv2.putText(img, label, (x-10,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)














print('Watching of ' + LOG_FILE + ' for ' + '*' + WATCH_FOR + '*' +
    ' started at ' + time.strftime('%Y-%m-%d %I:%M:%S %p'))








################################################
# Watch Logfile for new Motion Recording
################################################


mtime_last = 0
dtime_last = 0

net = cv2.dnn.readNet(args['weights'], args['config'])
mtime_cur = datetime.datetime.now()
recording_id = 'None'
recording_id_last = ''
centers_last = [-10, -10]
boxes_last = []

    
    
i = 1

now = datetime.datetime.now()
date_path = str(now.year) + '/' + (now.month if len(str(now.month)) == 2 else '0' + str(now.month)) + '/' + str(now.day)
# Monitor Log File:
for i in tail(LOG_FILE, 100):
    if WATCH_FOR.lower() in i.lower():
        mtime_cur = datetime.datetime.fromtimestamp(float(i.split(' ')[0]))
        camera_name_id = i.split("[")[1].split("]")[0].split("|")
        start = i.split("START:")[1].split(" ")[0]
        ts = datetime.datetime.fromtimestamp(int(start) / 1e3)
        recording_id = i.split("motionRecording:")[1].split(" ")[0]
        #recording_id = '5ba25ea1e4b0a01868310e29'
        if recording_id == recording_id_last:
            continue
        print('-------------------------------------------------------------------------------------------------------------------------------------')    
        print(str(ts) + '   Found Motion Recording on Camera ' + ' '.join(camera_name_id) + '. Recording ID is: ' + recording_id)



        confidences = []

        for root, directories, filenames in os.walk('/home/cichons/unifi-video/videos/'+ cameras[camera_name_id[1]] + '/' + date_path):
            for filename in filenames: 
                if fnmatch.fnmatch(filename, '*' + start + '*.mp4'):
                    video_path = root +'/' + filename
                if fnmatch.fnmatch(filename, '*' + recording_id + '*full.jpg'):
                    img_path = root +'/' + filename
                    print(str(ts) + '   Running Object detection on: \'' + img_path + '\' from Camera: \'' + ' '.join(camera_name_id) +'\' ...')
                    logger.info(str(ts) + '   Trigger Count: ' + str(i) + 'Motion detected on Camera: \'' + ' '.join(camera_name_id) +'\'   Running Object detection on: \'' + img_path + '\'')

                    # Detect Objects:
                    image = cv2.imread(img_path)
                    if image is not None:
                        try:
                            (Height, Width) = image.shape[:2]
                            blob = cv2.dnn.blobFromImage(image, scale, (416,416), (0,0,0), True, crop=False)
                            net.setInput(blob)
                            outs = net.forward(get_output_layers(net))

                            boxes = []
                            class_ids = []
                            dtime_cur = time.time()
                            confidences = []
                            centers = []
                            for out in outs:
                                for detection in out:
                                    scores = detection[5:]
                                    class_id = np.argmax(scores)
                                    confidence = scores[class_id]
                                    if confidence > conf_threshold and classes[class_id] in target_classes:
                                        print('confidence and class good')
                                        center_x = int(detection[0] * Width)
                                        center_y = int(detection[1] * Height)
                                        centers.append([center_x, center_y])
                                        w = int(detection[2] * Width)
                                        h = int(detection[3] * Height)
                                        x = center_x - w / 2
                                        y = center_y - h / 2
                                        class_ids.append(class_id)
                                        confidences.append(float(confidence))
                                        boxes.append([x, y, w, h])
                            if boxes == []:
                                print("No Object Detected.")
                                continue

                            indices = cv2.dnn.NMSBoxes(boxes, confidences, conf_threshold, nms_threshold)
                            if boxes != boxes_last:
                                print(boxes)
                                print(boxes_last)
                                for i in indices:
                                    i = i[0]
                                    box = boxes[i]
                                    x = box[0]
                                    y = box[1]
                                    w = box[2]
                                    h = box[3]
                                    draw_prediction(image, class_ids[i], confidences[i], round(x), round(y), round(x+w), round(y+h))

                                boxed_img_path = '/home/cichons/unifi-video/object_detections/'+ str(start) +'_'+ str(camera_name_id[1]) +'_'+ str(recording_id) + '.jpg' 
                                cv2.imwrite(boxed_img_path, image)


                                cv2.waitKey()
                                # Calculate relative Distances between centers of new and previous detections:                                        
                                distances = abs((centers_last) - np.array(centers))
                                
                                print('centers', centers)
                                print('centers_last', centers_last)
                                
                                if boxes != boxes_last and confidences and np.max(distances) > px_dist and (dtime_cur - dtime_last) > time_between_push_notifications:
                                    print('boxes differ', boxes != boxes_last)
                                    print('confidences good', confidences)
                                    print('distances ok', np.max(distances) > px_dist, distances)
                                    print('time between notifications?', (dtime_cur - dtime_last) > time_between_push_notifications)


                                    # Write to Log File
                                    logger.info(str(ts) + '   ' + ', '.join(list(set([classes[i] for i in class_ids]))) + 'Trigger Count: ' + str(i) + ' detected on Camera: \'' + ' '.join(camera_name_id) +'\'   Video path is: \'' + video_path + '\'')

                                    print(', '.join(list(set([classes[i] for i in class_ids]))) + ' detected!')

                                    # Sent Push Notification via Pushover:
                                    data['message'] = ', '.join(list(set([classes[i] for i in class_ids]))) + ' detected!'
                                    """
                                    r = requests.post("https://api.pushover.net/1/messages.json", data = data,
                                    files = {
                                      "attachment": (filename, open(boxed_img_path, "rb"), "image/jpeg")
                                    })
                                    print(r.text)
                                    """
                                    dtime_last = dtime_cur
                                else:
                                    print("Detected: " + ', '.join(list(set([classes[i] for i in class_ids]))) + ". Notification unwanted.")
                                    print('boxes differ', boxes != boxes_last)
                                    print('confidences good', confidences)
                                    print('distances to previous detections ok', np.max(distances) > px_dist, distances)
                                    print('time between notifications?', (dtime_cur - dtime_last) > time_between_push_notifications)
                                    continue

                            boxes_last = boxes
                            centers_last = centers

                        except Exception as err:
                            print(err)
                            continue

                    else:
                        print('image: ' + img_path + ' not found')
                        continue
        recording_id_last = recording_id
        recording_id = ''
# Out:
# Found Camera: Carport 539dc3f2-56e0-3007-8e4a-f62f1d8e8c81
# Watching of /home/cichons/unifi-video/logs/recording.log for *STOPPING REC* started at 2018-09-24 03:54:17 PM
# 2018-09-24 10:49:48.619000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8a532e4b0a018c79e7de1
# 2018-09-24 10:49:48.619000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8a532e4b0a018c79e7de1_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[885.0, 127.0, 736, 612]]
# []
# boxes differ True
# confidences good [0.9425026774406433]
# distances ok True [[1263  443]]
# time between notifications? True
# car detected!
# 2018-09-24 10:50:40.611000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8a566e4b0a018c79e7dec
# 2018-09-24 10:50:40.611000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8a566e4b0a018c79e7dec_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[897.0, 127.0, 718, 612]]
# [[885.0, 127.0, 736, 612]]
# Detected: car. Notification unwanted.
# boxes differ True
# confidences good [0.9784345030784607]
# distances to previous detections ok False [[3 0]]
# time between notifications? True
# 2018-09-24 10:51:52.608000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8a5afe4b0a018c79e7df9
# 2018-09-24 10:51:52.608000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8a5afe4b0a018c79e7df9_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[882.5, 128.5, 739, 609]]
# [[885.0, 127.0, 736, 612]]
# Detected: car. Notification unwanted.
# boxes differ True
# confidences good [0.8824447989463806]
# distances to previous detections ok False [[1 0]]
# time between notifications? True
# 2018-09-24 10:54:02.606000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8a631e4b0a018c79e7e03
# 2018-09-24 10:54:02.606000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8a631e4b0a018c79e7e03_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[901.5, 106.0, 699, 604]]
# [[885.0, 127.0, 736, 612]]
# boxes differ True
# confidences good [0.977136492729187]
# distances ok True [[ 2 25]]
# time between notifications? True
# car detected!
# 2018-09-24 10:55:14.599000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8a679e4b0a018c79e7e0c
# 2018-09-24 10:55:14.599000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8a679e4b0a018c79e7e0c_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[885.5, 118.0, 729, 626]]
# [[901.5, 106.0, 699, 604]]
# boxes differ True
# confidences good [0.9804956912994385]
# distances ok True [[ 1 23]]
# time between notifications? True
# car detected!
# 2018-09-24 10:56:16.601000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8a6b6e4b0a018c79e7e16
# 2018-09-24 10:56:16.601000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8a6b6e4b0a018c79e7e16_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[881.0, 122.5, 738, 621]]
# [[885.5, 118.0, 729, 626]]
# Detected: car. Notification unwanted.
# boxes differ True
# confidences good [0.9365283250808716]
# distances to previous detections ok False [[0 2]]
# time between notifications? True
# 2018-09-24 10:57:40.601000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8a70ce4b0a018c79e7e20
# 2018-09-24 10:57:40.601000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8a70ce4b0a018c79e7e20_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[880.0, 118.5, 746, 629]]
# [[885.5, 118.0, 729, 626]]
# Detected: car. Notification unwanted.
# boxes differ True
# confidences good [0.9816868901252747]
# distances to previous detections ok False [[3 2]]
# time between notifications? True
# 2018-09-24 10:58:12.595000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8a72ae4b0a018c79e7e2d
# 2018-09-24 10:58:12.595000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8a72ae4b0a018c79e7e2d_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[882.0, 114.0, 734, 636]]
# [[885.5, 118.0, 729, 626]]
# Detected: car. Notification unwanted.
# boxes differ True
# confidences good [0.9734029769897461]
# distances to previous detections ok False [[1 1]]
# time between notifications? True
# 2018-09-24 15:24:01.667000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8e576e4b02a5a1c106795
# 2018-09-24 15:24:01.667000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8e576e4b02a5a1c106795_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# confidence and class good
# [[885.0, 101.5, 730, 613], [905.5, 42.5, 79, 73]]
# [[885.5, 118.0, 729, 626]]
# boxes differ True
# confidences good [0.9786689281463623, 0.68382728099823]
# distances ok True [[  0  23]
#  [305 352]]
# time between notifications? True
# car detected!
# 2018-09-24 15:29:30.997000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8e6c0e4b02a5a1c10679f
# 2018-09-24 15:29:30.997000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8e6c0e4b02a5a1c10679f_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# confidence and class good
# [[889.0, 105.0, 730, 606], [911.5, 52.0, 77, 68]]
# [[885.0, 101.5, 730, 613], [905.5, 42.5, 79, 73]]
# Detected: car. Notification unwanted.
# boxes differ True
# confidences good [0.9846629500389099, 0.6542895436286926]
# distances to previous detections ok False [[4 0]
#  [5 7]]
# time between notifications? True
# 2018-09-24 15:32:28.977000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8e772e4b02a5a1c1067a8
# 2018-09-24 15:32:28.977000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8e772e4b02a5a1c1067a8_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[898.5, 94.0, 715, 628]]
# [[885.0, 101.5, 730, 613], [905.5, 42.5, 79, 73]]
# boxes differ True
# confidences good [0.9840828776359558]
# distances ok True [[  6   0]
#  [311 329]]
# time between notifications? True
# car detected!
# 2018-09-24 15:37:52.968000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8e8b6e4b02a5a1c1067b3
# 2018-09-24 15:37:52.968000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8e8b6e4b02a5a1c1067b3_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[901.0, 98.0, 712, 620]]
# [[898.5, 94.0, 715, 628]]
# Detected: car. Notification unwanted.
# boxes differ True
# confidences good [0.9857004880905151]
# distances to previous detections ok False [[1 0]]
# time between notifications? True
# 2018-09-24 15:40:38.971000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8e95ce4b02a5a1c1067be
# 2018-09-24 15:40:38.971000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8e95ce4b02a5a1c1067be_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# [[884.0, 97.0, 738, 620]]
# [[898.5, 94.0, 715, 628]]
# Detected: car. Notification unwanted.
# boxes differ True
# confidences good [0.9895778894424438]
# distances to previous detections ok False [[3 1]]
# time between notifications? True
# 2018-09-24 15:45:33.888000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8ea84e4b02a5a1c1067c7
# 2018-09-24 15:45:33.888000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8ea84e4b02a5a1c1067c7_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# confidence and class good
# [[888.5, 113.0, 739, 640], [911.5, 52.5, 75, 67]]
# [[898.5, 94.0, 715, 628]]
# boxes differ True
# confidences good [0.9886606931686401, 0.6322581171989441]
# distances ok True [[  2  25]
#  [307 322]]
# time between notifications? True
# car detected!
# 2018-09-24 15:48:47.890000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8eb45e4b02a5a1c1067d1
# 2018-09-24 15:48:47.890000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8eb45e4b02a5a1c1067d1_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# confidence and class good
# [[892.5, 100.5, 725, 613], [909.5, 51.5, 77, 69]]
# [[888.5, 113.0, 739, 640], [911.5, 52.5, 75, 67]]
# boxes differ True
# confidences good [0.9755309820175171, 0.5168976187705994]
# distances ok True [[ 3 26]
#  [ 1  0]]
# time between notifications? True
# car detected!
# 2018-09-24 15:49:05.890000   Found Motion Recording on Camera FCECDA8F6A0D Carport. Recording ID is: 5ba8eb58e4b02a5a1c1067da
# 2018-09-24 15:49:05.890000   Running Object detection on: '/home/cichons/unifi-video/videos/539dc3f2-56e0-3007-8e4a-f62f1d8e8c81/2018/09/24/meta/5ba8eb58e4b02a5a1c1067da_full.jpg' from Camera: 'FCECDA8F6A0D Carport' ...
# confidence and class good
# confidence and class good
# [[883.5, 118.5, 745, 633], [906.0, 45.5, 82, 69]]
# [[892.5, 100.5, 725, 613], [909.5, 51.5, 77, 69]]
# boxes differ True
# confidences good [0.980705201625824, 0.7550157904624939]
# distances ok True [[ 1 28]
#  [ 1  6]]
# time between notifications? True
# car detected!

# %%
centers_last = [[1250, 408], [945, 79]]
centers = [[950, 86]]

# %%
distances = []
for c in centers:
    for cl in centers_last:
        #distances.append(np.mean((np.array(c) - np.array(cl))/(image.shape[0]*image.shape[0])))
        distances.append(sum(np.array(c) - np.array(cl)))

# %%
distances
# Out:
# [4, 638, -622, 12]

# %%
np.max(abs((centers_last) - np.array(centers)))
# Out:
# 322
